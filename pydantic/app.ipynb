# %%
from pydantic import BaseModel

# %%
from dataclasses import dataclass

@dataclass
class Person():
    name: str
    age: int
    city: str

person = Person(name="Yash", age=25, city="Surat")
print(person)
# Out:
# Person(name='Yash', age=25, city='Surat')

# %%
class Person(BaseModel):
    name: str
    age: int
    city: str

person1 = Person(name="Yash", age=25, city="Surat")
print(person1)
# Out:
# name='Yash' age=25 city='Surat'

# %%
from typing import Optional

class Employee(BaseModel):
    id: int
    name: str
    department: str
    salary: Optional[float] = None  # Optional with defalut value
    is_active: Optional[bool] = True # Optional with defalut True

# %%
# Examples with and without optional fileds

emp1 = Employee(id=1, name="Yash", department="IT")
print(emp1)
# Out:
# id=1 name='Yash' department='IT' salary=None is_active=True

# %%
from pydantic import BaseModel

class Address(BaseModel):
    street: str
    city: str
    zip_code: str

class Customer(BaseModel):
    customer_id: int
    name: str
    address: Address #Nested model

# Create  a customer with nested address
customer = Customer(
    customer_id=1,
    name="Yash",
    address={"street": "123 Main Street", "city": "Surat", "zip_code": "395010"}
)

print(customer)
# Out:
# customer_id=1 name='Yash' address=Address(street='123 Main Street', city='Surat', zip_code='395010')

# %%
print(Customer.model_json_schema())
# Out:
# {'$defs': {'Address': {'properties': {'street': {'title': 'Street', 'type': 'string'}, 'city': {'title': 'City', 'type': 'string'}, 'zip_code': {'title': 'Zip Code', 'type': 'string'}}, 'required': ['street', 'city', 'zip_code'], 'title': 'Address', 'type': 'object'}}, 'properties': {'customer_id': {'title': 'Customer Id', 'type': 'integer'}, 'name': {'title': 'Name', 'type': 'string'}, 'address': {'$ref': '#/$defs/Address'}}, 'required': ['customer_id', 'name', 'address'], 'title': 'Customer', 'type': 'object'}
